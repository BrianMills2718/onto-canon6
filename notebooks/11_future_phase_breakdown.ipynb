# %% [markdown]
# # Phase 10 Workflow Completion
#
# This notebook records the locked Phase 10 workflow choice and the remaining post-roadmap questions after the successor reached a real product-facing slice.
#
# The workflow is now proved in `notebooks/16_governed_bundle_workflow.ipynb`. This companion explains what was chosen and what remains deliberately deferred.

# %%
from __future__ import annotations

from pprint import pprint

# %%
phase10_choice = {
    'workflow': 'CLI-backed governed bundle export',
    'input': 'source text file',
    'output': 'governed JSON bundle over accepted candidate assertions',
    'why': [
        'It delivers a real downstream artifact instead of raw list outputs.',
        'It reuses the proved services instead of adding a new runtime.',
        'It keeps MCP deferred until there is actual consumer pressure.',
    ],
}

pprint(phase10_choice)
# Out:
# {'input': 'source text file',
#  'output': 'governed JSON bundle over accepted candidate assertions',
#  'why': ['It delivers a real downstream artifact instead of raw list outputs.',
#          'It reuses the proved services instead of adding a new runtime.',
#          'It keeps MCP deferred until there is actual consumer pressure.'],
#  'workflow': 'CLI-backed governed bundle export'}

# %%
bundle_shape = {
    'accepted_candidate_fields': [
        'candidate payload',
        'source provenance',
        'evidence spans',
        'linked proposals',
        'overlay applications',
        'artifact lineage when present',
        'epistemic state when present',
    ],
    'summary_fields': [
        'total_candidates',
        'total_linked_proposals',
        'total_overlay_applications',
        'total_candidates_with_artifacts',
        'total_candidates_with_confidence',
        'total_superseded_candidates',
    ],
}

pprint(bundle_shape)
# Out:
# {'accepted_candidate_fields': ['candidate payload',
#                                'source provenance',
#                                'evidence spans',
#                                'linked proposals',
#                                'overlay applications',
#                                'artifact lineage when present',
#                                'epistemic state when present'],
#  'summary_fields': ['total_candidates',
#                     'total_linked_proposals',
#                     'total_overlay_applications',
#                     'total_candidates_with_artifacts',
#                     'total_candidates_with_confidence',
#                     'total_superseded_candidates']}

# %%
post_roadmap_questions = {
    'mcp_timing': 'Do not add MCP until a real consumer needs it over the governed bundle surface.',
    'benchmark_growth': 'Expand benchmark coverage only when the added corpus changes real workflow confidence.',
    'next_workflow_pressure': 'Extend the roadmap only when a concrete consumer or workflow demands it.',
}

pprint(post_roadmap_questions)
# Out:
# {'benchmark_growth': 'Expand benchmark coverage only when the added corpus '
#                      'changes real workflow confidence.',
#  'mcp_timing': 'Do not add MCP until a real consumer needs it over the '
#                'governed bundle surface.',
#  'next_workflow_pressure': 'Extend the roadmap only when a concrete consumer '
#                            'or workflow demands it.'}
